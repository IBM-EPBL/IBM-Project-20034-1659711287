# %% [markdown]
# # IMPORT THE NECESSARY LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # READING THE DATASET

# %%
df=pd.read_csv('Water_potability.csv',encoding='ISO-8859-1',low_memory=False)
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# # info() method is used to get the columns in the dataset along with its properties

# %%
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %% [markdown]
# # HANDLING THE MISSING VALUES

# %%
df.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %% [markdown]
# # Here there is the null values present in the dataset

# %%
df.dtypes
# Out:
# ph                 float64
# Hardness           float64
# Solids             float64
# Chloramines        float64
# Sulfate            float64
# Conductivity       float64
# Organic_carbon     float64
# Trihalomethanes    float64
# Turbidity          float64
# Potability           int64
# dtype: object

# %% [markdown]
# # Here many numeric columns has the datatype of floa

# %%
df.fillna(df.mean(),inplace=True

# %%
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
df.shape
# Out:
# (3276, 10)

# %% [markdown]
# # The above dataset contains 3276 rows and 12 columns

# %% [markdown]
# # DESCRIPTIVE STATISTICS OF THE DATASET

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %% [markdown]
# # The above shows only the descriptive statistics of the column because it is the only column which has the datatype 'int64'

# %%
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %% [markdown]
# # So,the dataset hasbeen read,analsed and preprocessing hasbeen done successfully

# %% [markdown]
# # CHECKING IF WE NEED TO DO DIMENSIOLILITY REDUCTION

# %%
sns.heatmap(df.corr())
plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
fig=plt.gcf()
fig.set_size_inches(8,6)
plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
fig=plt.gcf()
fig.set_size_inches(8,6)
plt.show()

# %%
sns.heatmap(df.corr(),annot=True,cmap='terrain')
plt.figure(figsize=(11,7))
plt.show()

# %%
sns.heatmap(df.corr(),annot=True,cmap='terrain')
plt.figure(figsize=(25,7))
plt.show()

# %% [markdown]
# # LET'S CHECK THE BOX PLOT

# %%
df.boxplot()
plt.show()

# %%
df.boxplot(figsize=(13,6))
plt.show()

# %%
df['Solids'].describe()
# Out:
# count     3276.000000
# mean     22014.092526
# std       8768.570828
# min        320.942611
# 25%      15666.690297
# 50%      20927.833607
# 75%      27332.762127
# max      61227.196008
# Name: Solids, dtype: float64

# %%
df['Solids']
# Out:
# 0       20791.318981
# 1       18630.057858
# 2       19909.541732
# 3       22018.417441
# 4       17978.986339
#             ...
# 3271    47580.991603
# 3272    17329.802160
# 3273    33155.578218
# 3274    11983.869376
# 3275    17404.177061
# Name: Solids, Length: 3276, dtype: float64

# %% [markdown]
# # VARIOUS PLOTTING ANALYSIS

# %%
sns.displot(df.ph)

# %%
df.plot.line()
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %%
df = pd.read_csv("water_potability.csv")
pd.isnull(df["ph"])
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3271    False
# 3272    False
# 3273    False
# 3274    False
# 3275    False
# Name: ph, Length: 3276, dtype: bool

# %%
df = pd.read_csv("water_potability.csv")
pd.isnull(df["Conductivity"])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3271    False
# 3272    False
# 3273    False
# 3274    False
# 3275    False
# Name: Conductivity, Length: 3276, dtype: bool

# %%
X = df.iloc[:, :-2].values
print(X)
# Out:
# [[           nan 2.04890455e+02 2.07913190e+04 ... 5.64308654e+02
#   1.03797831e+01 8.69909705e+01]
#  [3.71608008e+00 1.29422921e+02 1.86300579e+04 ... 5.92885359e+02
#   1.51800131e+01 5.63290763e+01]
#  [8.09912419e+00 2.24236259e+02 1.99095417e+04 ... 4.18606213e+02
#   1.68686369e+01 6.64200925e+01]
#  ...
#  [9.41951032e+00 1.75762646e+02 3.31555782e+04 ... 4.32044783e+02
#   1.10390697e+01 6.98454003e+01]
#  [5.12676292e+00 2.30603758e+02 1.19838694e+04 ... 4.02883113e+02
#   1.11689462e+01 7.74882131e+01]
#  [7.87467136e+00 1.95102299e+02 1.74041771e+04 ... 3.27459760e+02
#   1.61403676e+01 7.86984463e+01]]

# %%
Y = df.iloc[:, -1].values
print(Y)
# Out:
# [0 0 0 ... 1 1 1]

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[["Hardness"]] = scaler.fit_transform(df[["Hardness"]])
print(df)
# Out:
#             ph  Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0          NaN  0.571139  20791.318981     7.300212  368.516441    564.308654
# 1     3.716080  0.297400  18630.057858     6.635246         NaN    592.885359
# 2     8.099124  0.641311  19909.541732     9.275884         NaN    418.606213
# 3     8.316766  0.605536  22018.417441     8.059332  356.886136    363.266516
# 4     9.092223  0.484851  17978.986339     6.546600  310.135738    398.410813
# ...        ...       ...           ...          ...         ...           ...
# 3271  4.668102  0.530482  47580.991603     7.166639  359.948574    526.424171
# 3272  7.808856  0.530016  17329.802160     8.061362         NaN    392.449580
# 3273  9.419510  0.465486  33155.578218     7.350233         NaN    432.044783
# 3274  5.126763  0.664407  11983.869376     6.303357         NaN    402.883113
# 3275  7.874671  0.535635  17404.177061     7.509306         NaN    327.459760
#
# ...

# %%
from sklearn.model_selection import train_test_split
train_size=0.8
X = df.drop(columns = ['ph']).copy()
y = df['ph']
X_train, X_rem, y_train, y_rem = train_test_split(X,y, train_size=0.8)
test_size = 0.5
X_valid, X_test, y_valid, y_test = train_test_split(X_rem,y_rem, test_size=0.5)
print(X_train.shape), print(y_train.shape)
print(X_valid.shape), print(y_valid.shape)
print(X_test.shape), print(y_test.shape)
# Out:
# (2620, 9)
# (2620,)
# (328, 9)
# (328,)
# (328, 9)
# (328,)
# (None, None)

# %%
df['nHardness']=df.Hardness.apply(lambda x: (100 if (x>=6)
else(80 if (6>=x>=5.1)
else(60 if (5>=x>=4.1)
else(40 if (4>=x>=3)
else 0)))))

# %%
df['Solids']=df.Solids.apply(lambda x:(100 if (5>=x>=0)
else(80 if (50>=x>=5)
else(60 if (500>=x>=50)
else(40 if (10000>=x>=500)
else 0)))))

# %% [markdown]
# # CALCULATION OF WATER QUALITY INDEX

# %%
df['wph']=df.ph*0.165
df['wHardness']=df.nHardness*0.281
df['wSolids']=df.Solids*0.281
df['wqi']=df.wph+df.wHardness+df.wSolids
df
# Out:
#             ph  Hardness  Solids  Chloramines     Sulfate  Conductivity  \
# 0          NaN  0.571139       0     7.300212  368.516441    564.308654
# 1     3.716080  0.297400       0     6.635246         NaN    592.885359
# 2     8.099124  0.641311       0     9.275884         NaN    418.606213
# 3     8.316766  0.605536       0     8.059332  356.886136    363.266516
# 4     9.092223  0.484851       0     6.546600  310.135738    398.410813
# ...        ...       ...     ...          ...         ...           ...
# 3271  4.668102  0.530482       0     7.166639  359.948574    526.424171
# 3272  7.808856  0.530016       0     8.061362         NaN    392.449580
# 3273  9.419510  0.465486       0     7.350233         NaN    432.044783
# 3274  5.126763  0.664407       0     6.303357         NaN    402.883113
# 3275  7.874671  0.535635       0     7.509306         NaN    327.459760
#
#       Organic_carbon  Trihalomethanes  Turbidity  Potability  nHardness  \
# ...

# %%
average=df.groupby('Potability')['wqi'].mean()

# %% [markdown]
# # VARIOUS DATA VISUALISATIONS

# %% [markdown]
# # 1. Univariate Visualisations

# %%
for col in df.columns:
    if df.dtypes[col]=='float64'or df.dtypes[col]=='int64':
        sns.boxplot(x=df[col]).set(xlabel=col)
        plt.show()

# %% [markdown]
# # 2.Bivariate Visualisations

# %%
for col in df.columns:
    if df.dtypes[col]=='float64':
        sns.distplot(x=df[col]).set(xlabel=col)
        plt.show()
# Out:
# C:\Users\RAJA\ann\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\RAJA\ann\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # 3.Multivariate Visualisations

# %%
df.corr()
# Out:
#                        ph  Hardness    Solids  Chloramines   Sulfate  \
# ph               1.000000  0.082096  0.071918    -0.034350  0.018203
# Hardness         0.082096  1.000000  0.047708    -0.030054 -0.106923
# Solids           0.071918  0.047708  1.000000     0.056351  0.070141
# Chloramines     -0.034350 -0.030054  0.056351     1.000000  0.027244
# Sulfate          0.018203 -0.106923  0.070141     0.027244  1.000000
# Conductivity     0.018614 -0.023915 -0.034163    -0.020486 -0.016121
# Organic_carbon   0.043503  0.003610 -0.002166    -0.012653  0.030831
# Trihalomethanes  0.003354 -0.013013 -0.005536     0.017084 -0.030274
# Turbidity       -0.039057 -0.014449 -0.006818     0.002363 -0.011187
# Potability      -0.003556 -0.013837  0.001021     0.023779 -0.023577
# nHardness             NaN       NaN       NaN          NaN       NaN
# wph              1.000000  0.082096  0.071918    -0.034350  0.018203
# wHardness             NaN       NaN       NaN          NaN       NaN
# ...

# %% [markdown]
# # Splitting Dataset into Dependent and Independent Columns

# %%
x=df.iloc[:,0:7].values
y=df.iloc[:,7:].values

# %%
x.shape
# Out:
# (3276, 7)

# %%
y.shape
# Out:
# (3276, 8)

# %%
x
# Out:
# array([[           nan, 5.71139008e-01, 0.00000000e+00, ...,
#         3.68516441e+02, 5.64308654e+02, 1.03797831e+01],
#        [3.71608008e+00, 2.97400434e-01, 0.00000000e+00, ...,
#                    nan, 5.92885359e+02, 1.51800131e+01],
#        [8.09912419e+00, 6.41310808e-01, 0.00000000e+00, ...,
#                    nan, 4.18606213e+02, 1.68686369e+01],
#        ...,
#        [9.41951032e+00, 4.65485565e-01, 0.00000000e+00, ...,
#                    nan, 4.32044783e+02, 1.10390697e+01],
#        [5.12676292e+00, 6.64407228e-01, 0.00000000e+00, ...,
#                    nan, 4.02883113e+02, 1.11689462e+01],
#        [7.87467136e+00, 5.35635051e-01, 0.00000000e+00, ...,
#                    nan, 3.27459760e+02, 1.61403676e+01]])

# %%
y
# Out:
# array([[86.99097046,  2.96313538,  0.        , ...,  0.        ,
#          0.        ,         nan],
#        [56.32907628,  4.50065627,  0.        , ...,  0.        ,
#          0.        ,  0.61315321],
#        [66.42009251,  3.05593375,  0.        , ...,  0.        ,
#          0.        ,  1.33635549],
#        ...,
#        [69.84540029,  3.2988755 ,  1.        , ...,  0.        ,
#          0.        ,  1.5542192 ],
#        [77.4882131 ,  4.70865847,  1.        , ...,  0.        ,
#          0.        ,  0.84591588],
#        [78.69844633,  2.30914906,  1.        , ...,  0.        ,
#          0.        ,  1.29932077]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)
x_train.shape
# Out:
# (2620, 7)

# %%
y_train.shape
# Out:
# (2620, 8)

# %%
y_test.shape
# Out:
# (656, 8)

# %%
x_test.shape
# Out:
# (656, 7)

# %% [markdown]
# # We have calculated the Water Quality Index value from various WQI determining parameters and performed various visualisations in the Dataset.

# %% [markdown]
# # Also, we have split the Dependent and Independent columns and also have split the data into training and testing.
